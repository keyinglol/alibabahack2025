# %%
# read as pd
import pandas as pd

df = pd.read_csv("coffee_shop_sales.csv")

# %%
# import pandas as pd
# from sqlalchemy import create_engine

# # === RDS MySQL Connection Details ===
# rds_endpoint = 'rm-3ns07g63ft07gwue9no.mysql.rds.aliyuncs.com'
# rds_port = 3306
# rds_dbname = 'coffee'
# rds_user = 'jienweng'
# rds_pass = 'Test1234'

# # === Create SQLAlchemy engine ===
# engine = create_engine(f'mysql+pymysql://{rds_user}:{rds_pass}@{rds_endpoint}:{rds_port}/{rds_dbname}')

# # === Upload to RDS: auto-create table, overwrite if exists ===
# df.to_sql('raw_data', con=engine, index=False, if_exists='replace')

# print("✅ Table `raw_data` created/replaced and data uploaded successfully.")

# %%
# check_df = pd.read_sql("SELECT * FROM raw_data LIMIT 5", con=engine)
# print("Preview of uploaded table:")
# print(check_df)

# %%
df
# Out:
#         transaction_id transaction_date transaction_time  transaction_qty  \
# 0                    1       01/01/2023          7:06:11                2
# 1                    2       01/01/2023          7:08:56                2
# 2                    3       01/01/2023          7:14:04                2
# 3                    4       01/01/2023          7:20:24                1
# 4                    5       01/01/2023          7:22:41                2
# ...                ...              ...              ...              ...
# 149111          149452       30/06/2023         20:18:41                2
# 149112          149453       30/06/2023         20:25:10                2
# 149113          149454       30/06/2023         20:31:34                1
# 149114          149455       30/06/2023         20:57:19                1
# 149115          149456       30/06/2023         20:57:19                2
#
#         store_id   store_location  product_id  unit_price    product_category  \
# ...

# %%
df["product_detail"].unique()
# Out:
# array(['Ethiopia Rg', 'Spicy Eye Opener Chai Lg', 'Dark chocolate Lg',
#        'Our Old Time Diner Blend Sm', 'Oatmeal Scone',
#        'Columbian Medium Roast Sm', 'Latte Rg', 'Dark chocolate Rg',
#        'Spicy Eye Opener Chai Rg', 'Ethiopia Lg', 'Earl Grey Lg',
#        'Ouro Brasileiro shot', 'Serenity Green Tea Lg',
#        'Jumbo Savory Scone', 'Lemon Grass Rg',
#        'Sustainably Grown Organic Lg', 'Hazelnut Biscotti', 'Cappuccino',
#        'Lemon Grass Lg', 'Chocolate Chip Biscotti', 'Peppermint Lg',
#        'Chocolate Croissant', 'Latte', 'Brazilian Rg', 'Brazilian Lg',
#        'Columbian Medium Roast Rg', 'Morning Sunrise Chai Rg',
#        'Morning Sunrise Chai Lg', 'Our Old Time Diner Blend Lg',
#        'Sustainably Grown Organic Rg', 'Scottish Cream Scone ',
#        'Peppermint Rg', 'English Breakfast Rg',
#        'Our Old Time Diner Blend Rg', 'Serenity Green Tea Rg',
#        'Brazilian Sm', 'Jamaican Coffee River Sm',
# ...

# %%
# Convert transaction_date to datetime.date format
df['transaction_date'] = pd.to_datetime(df['transaction_date'], format='%d/%m/%Y').dt.date

# Convert transaction_time to datetime.time format
df['transaction_time'] = pd.to_datetime(df['transaction_time'], format='%H:%M:%S').dt.time

# %%
df
# Out:
#         transaction_id transaction_date transaction_time  transaction_qty  \
# 0                    1       2023-01-01         07:06:11                2
# 1                    2       2023-01-01         07:08:56                2
# 2                    3       2023-01-01         07:14:04                2
# 3                    4       2023-01-01         07:20:24                1
# 4                    5       2023-01-01         07:22:41                2
# ...                ...              ...              ...              ...
# 149111          149452       2023-06-30         20:18:41                2
# 149112          149453       2023-06-30         20:25:10                2
# 149113          149454       2023-06-30         20:31:34                1
# 149114          149455       2023-06-30         20:57:19                1
# 149115          149456       2023-06-30         20:57:19                2
#
#         store_id   store_location  product_id  unit_price    product_category  \
# ...

# %%
# based on transaction_date, add a column to the dataframe that indicates the day of the week
df['day_of_week'] = df['transaction_date'].apply(lambda x: x.strftime('%A'))
# based on transaction_date, add a column to the dataframe that indicates the month
df['month'] = df['transaction_date'].apply(lambda x: x.strftime('%B'))
# based on transaction_date, add a column to the dataframe that indicates the year
df['year'] = df['transaction_date'].apply(lambda x: x.strftime('%Y'))
# based on transaction_time, add a column to the dataframe that indicates the hour
df['hour'] = df['transaction_time'].apply(lambda x: x.strftime('%H'))

df
# Out:
#         transaction_id transaction_date transaction_time  transaction_qty  \
# 0                    1       2023-01-01         07:06:11                2
# 1                    2       2023-01-01         07:08:56                2
# 2                    3       2023-01-01         07:14:04                2
# 3                    4       2023-01-01         07:20:24                1
# 4                    5       2023-01-01         07:22:41                2
# ...                ...              ...              ...              ...
# 149111          149452       2023-06-30         20:18:41                2
# 149112          149453       2023-06-30         20:25:10                2
# 149113          149454       2023-06-30         20:31:34                1
# 149114          149455       2023-06-30         20:57:19                1
# 149115          149456       2023-06-30         20:57:19                2
#
#         store_id   store_location  product_id  unit_price    product_category  \
# ...

# %%
# plot the sum of unit_price by date in line plot
import matplotlib.pyplot as plt
import seaborn as sns
plt.figure(figsize=(12, 6))
sns.lineplot(data=df, x='transaction_date', y='unit_price', estimator='sum')
plt.title('Sum of Unit Price by Transaction Date')
plt.xlabel('Transaction Date')
plt.ylabel('Sum of Unit Price')
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %%
df.columns
# Out:
# Index(['transaction_id', 'transaction_date', 'transaction_time',
#        'transaction_qty', 'store_id', 'store_location', 'product_id',
#        'unit_price', 'product_category', 'product_type', 'product_detail',
#        'day_of_week', 'month', 'year', 'hour'],
#       dtype='object')

# %% [markdown]
# # Holidays

# %%
import holidays

# Get Malaysian holidays for the years in your dataset
# First, determine the range of years in your data
min_year = int(df['year'].min())
max_year = int(df['year'].max())

# Create a Malaysian holiday calendar
my_holidays = holidays.US(years=range(min_year, max_year + 1))

# Convert transaction_date to datetime if it's not already
if not pd.api.types.is_datetime64_any_dtype(df['transaction_date']):
    df['transaction_date'] = pd.to_datetime(df['transaction_date'])

# Check if each date is a holiday
df['is_public_holiday'] = df['transaction_date'].apply(lambda x: 1 if x in my_holidays else 0)

# If you want the holiday name as well
df['holiday_name'] = df['transaction_date'].apply(lambda x: my_holidays.get(x) if x in my_holidays else None)

# %%
df
# Out:
#         transaction_id transaction_date transaction_time  transaction_qty  \
# 0                    1       2023-01-01         07:06:11                2
# 1                    2       2023-01-01         07:08:56                2
# 2                    3       2023-01-01         07:14:04                2
# 3                    4       2023-01-01         07:20:24                1
# 4                    5       2023-01-01         07:22:41                2
# ...                ...              ...              ...              ...
# 149111          149452       2023-06-30         20:18:41                2
# 149112          149453       2023-06-30         20:25:10                2
# 149113          149454       2023-06-30         20:31:34                1
# 149114          149455       2023-06-30         20:57:19                1
# 149115          149456       2023-06-30         20:57:19                2
#
#         store_id   store_location  product_id  unit_price    product_category  \
# ...

# %%
df[df["is_public_holiday"]==1]
# Out:
#         transaction_id transaction_date transaction_time  transaction_qty  \
# 0                    1       2023-01-01         07:06:11                2
# 1                    2       2023-01-01         07:08:56                2
# 2                    3       2023-01-01         07:14:04                2
# 3                    4       2023-01-01         07:20:24                1
# 4                    5       2023-01-01         07:22:41                2
# ...                ...              ...              ...              ...
# 136408          136745       2023-06-19         19:52:19                1
# 136409          136746       2023-06-19         19:53:39                1
# 136410          136747       2023-06-19         19:54:34                2
# 136411          136748       2023-06-19         19:57:05                2
# 136412          136749       2023-06-19         19:57:19                1
#
#         store_id   store_location  product_id  unit_price    product_category  \
# ...

# %% [markdown]
# # is_weekend

# %%
df['is_weekend'] = df['day_of_week'].apply(lambda x: 1 if x in ['Saturday', 'Sunday'] else 0)

# %% [markdown]
# # week_of_month

# %%
import numpy as np
# Calculate day of month from transaction_date
df['day_of_month'] = df['transaction_date'].apply(lambda x: x.day)
# Calculate week of month (1-indexed)
df['week_of_month'] = np.ceil(df['day_of_month'] / 7).astype(int)

# %%
df
# Out:
#         transaction_id transaction_date transaction_time  transaction_qty  \
# 0                    1       2023-01-01         07:06:11                2
# 1                    2       2023-01-01         07:08:56                2
# 2                    3       2023-01-01         07:14:04                2
# 3                    4       2023-01-01         07:20:24                1
# 4                    5       2023-01-01         07:22:41                2
# ...                ...              ...              ...              ...
# 149111          149452       2023-06-30         20:18:41                2
# 149112          149453       2023-06-30         20:25:10                2
# 149113          149454       2023-06-30         20:31:34                1
# 149114          149455       2023-06-30         20:57:19                1
# 149115          149456       2023-06-30         20:57:19                2
#
#         store_id   store_location  product_id  unit_price    product_category  \
# ...

# %%
df.columns
# Out:
# Index(['transaction_id', 'transaction_date', 'transaction_time',
#        'transaction_qty', 'store_id', 'store_location', 'product_id',
#        'unit_price', 'product_category', 'product_type', 'product_detail',
#        'day_of_week', 'month', 'year', 'hour', 'is_public_holiday',
#        'holiday_name', 'is_weekend', 'day_of_month', 'week_of_month'],
#       dtype='object')

# %%
import pandas as pd
from sqlalchemy import create_engine

# === RDS MySQL Connection Details ===
rds_endpoint = "rm-3ns023t5i1ctk89e5go.mysql.rds.aliyuncs.com"
rds_port = 3306
rds_dbname = 'cleaned_data'
rds_user = 'adminAcc'
rds_pass = 'Test1234'

# === Create SQLAlchemy engine ===
engine = create_engine(f'mysql+pymysql://{rds_user}:{rds_pass}@{rds_endpoint}:{rds_port}/{rds_dbname}')

# === Upload to RDS: auto-create table, overwrite if exists ===
df.to_sql('cleaned_data', con=engine, index=False, if_exists='replace')

print("Table created/replaced and data uploaded successfully.")
# Out:
# ---------------------------------------------------------------------------
# PendingRollbackError                      Traceback (most recent call last)
# Cell In[75], line 15
#      12 engine = create_engine(f'mysql+pymysql://{rds_user}:{rds_pass}@{rds_endpoint}:{rds_port}/{rds_dbname}')
#      14 # === Upload to RDS: auto-create table, overwrite if exists ===
# ---> 15 df.to_sql('cleaned_data', con=engine, index=False, if_exists='replace')
#      17 print("Table created/replaced and data uploaded successfully.")
#
# File ~/anaconda3/lib/python3.12/site-packages/pandas/util/_decorators.py:333, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     327 if len(args) > num_allow_args:
#     328     warnings.warn(
#     329         msg.format(arguments=_format_argument_list(allow_args)),
#     330         FutureWarning,
#     331         stacklevel=find_stack_level(),
#     332     )
# --> 333 return func(*args, **kwargs)
#
# ...

# %%
check_df = pd.read_sql("SELECT * FROM cleaned_data LIMIT 5", con=engine)
print("Preview of uploaded table:")
print(check_df)
# Out:
# Preview of uploaded table:
#    transaction_id transaction_date transaction_time  transaction_qty  \
# 0               1       2023-01-01  0 days 07:06:11                2
# 1               2       2023-01-01  0 days 07:08:56                2
# 2               3       2023-01-01  0 days 07:14:04                2
# 3               4       2023-01-01  0 days 07:20:24                1
# 4               5       2023-01-01  0 days 07:22:41                2
#
#    store_id   store_location  product_id  unit_price    product_category  \
# 0         5  Lower Manhattan          32         3.0              Coffee
# 1         5  Lower Manhattan          57         3.1                 Tea
# 2         5  Lower Manhattan          59         4.5  Drinking Chocolate
# 3         5  Lower Manhattan          22         2.0              Coffee
# 4         5  Lower Manhattan          57         3.1                 Tea
#
#             product_type               product_detail day_of_week    month  \
# ...

# %%
print(f'mysql+pymysql://{rds_user}:{rds_pass}@{rds_endpoint}:{rds_port}/{rds_dbname}')
# Out:
# mysql+pymysql://adminAcc:Test1234@rm-3ns023t5i1ctk89e5go.mysql.rds.aliyuncs.com:3306/cleaned_data

# %%
df.columns
# Out:
# Index(['transaction_id', 'transaction_date', 'transaction_time',
#        'transaction_qty', 'store_id', 'store_location', 'product_id',
#        'unit_price', 'product_category', 'product_type', 'product_detail',
#        'day_of_week', 'month', 'year', 'hour', 'is_public_holiday',
#        'holiday_name', 'is_weekend', 'day_of_month', 'week_of_month'],
#       dtype='object')

# %%
# Calculate sales amount first
df['sales_amount'] = df['transaction_qty'] * df['unit_price']

# Group by date and product_type, aggregate
daily_summary = df.groupby(['transaction_date', 'product_type']).agg(
    total_quantity_sold = ('transaction_qty', 'sum'),
    avg_unit_price = ('unit_price', 'mean'),
    total_sales_amount = ('sales_amount', 'sum')
).reset_index()

# Round the relevant columns
daily_summary['avg_unit_price'] = daily_summary['avg_unit_price'].round(2)
daily_summary['total_sales_amount'] = daily_summary['total_sales_amount'].round(2)

# %%
# create a database for product id with corresponding product_detail and product_category and unit price
product_info = df[['product_id', 'product_detail', 'product_category', 'unit_price']].drop_duplicates()

# sort by product_id
product_info = product_info.sort_values(by='product_id').reset_index(drop=True)

# for duplicate product_id, keep the first occurrence
product_info = product_info.drop_duplicates(subset=['product_id'], keep='first')
product_info = product_info.reset_index(drop=True)

# %%
product_info
# Out:
#     product_id             product_detail product_category  unit_price
# 0            1        Brazilian - Organic     Coffee beans       18.00
# 1            2   Our Old Time Diner Blend     Coffee beans       18.00
# 2            3             Espresso Roast     Coffee beans       14.75
# 3            4       Primo Espresso Roast     Coffee beans       20.45
# 4            5     Columbian Medium Roast     Coffee beans       15.00
# ..         ...                        ...              ...         ...
# 75          81    I Need My Bean! T-shirt          Branded       28.00
# 76          82  I Need My Bean! Diner mug          Branded       12.00
# 77          83  I Need My Bean! Latte cup          Branded       23.00
# 78          84            Chocolate syrup         Flavours        0.80
# 79          87       Ouro Brasileiro shot           Coffee        2.10
#
# [80 rows x 4 columns]

# %%
product_info.to_sql('product_info', con=engine, index=False, if_exists='replace')
# Out:
# 80

# %%
product_info = pd.read_sql("SELECT * FROM product_info", con=engine)
print("Preview of uploaded table:")
print(product_info)
# Out:
# Preview of uploaded table:
#     product_id             product_detail product_category  unit_price
# 0            1        Brazilian - Organic     Coffee beans       18.00
# 1            2   Our Old Time Diner Blend     Coffee beans       18.00
# 2            3             Espresso Roast     Coffee beans       14.75
# 3            4       Primo Espresso Roast     Coffee beans       20.45
# 4            5     Columbian Medium Roast     Coffee beans       15.00
# ..         ...                        ...              ...         ...
# 75          81    I Need My Bean! T-shirt          Branded       28.00
# 76          82  I Need My Bean! Diner mug          Branded       12.00
# 77          83  I Need My Bean! Latte cup          Branded       23.00
# 78          84            Chocolate syrup         Flavours        0.80
# 79          87       Ouro Brasileiro shot           Coffee        2.10
#
# [80 rows x 4 columns]

# %%
# create a df for store id with correpsponding store location
store_info = df[['store_id', 'store_location']].drop_duplicates()
# sort by store_id
store_info = store_info.sort_values(by='store_id').reset_index(drop=True)

store_info
# Out:
#    store_id   store_location
# 0         3          Astoria
# 1         5  Lower Manhattan
# 2         8   Hell's Kitchen

# %%
store_info.to_sql('store_info', con=engine, index=False, if_exists='replace')
# Out:
# 3

# %%
store_info = pd.read_sql("SELECT * FROM store_info", con=engine)
print("Preview of uploaded table:")
print(store_info)
# Out:
# Preview of uploaded table:
#    store_id   store_location
# 0         3          Astoria
# 1         5  Lower Manhattan
# 2         8   Hell's Kitchen

# %%
# from df, drop product_detail, product_category, unit_price, store_location
df = df.drop(columns=['product_detail', 'product_type','product_category', 'unit_price', 'store_location'])

# %%
df
# Out:
#         transaction_id transaction_date transaction_time  transaction_qty  \
# 0                    1       2023-01-01         07:06:11                2
# 1                    2       2023-01-01         07:08:56                2
# 2                    3       2023-01-01         07:14:04                2
# 3                    4       2023-01-01         07:20:24                1
# 4                    5       2023-01-01         07:22:41                2
# ...                ...              ...              ...              ...
# 149111          149452       2023-06-30         20:18:41                2
# 149112          149453       2023-06-30         20:25:10                2
# 149113          149454       2023-06-30         20:31:34                1
# 149114          149455       2023-06-30         20:57:19                1
# 149115          149456       2023-06-30         20:57:19                2
#
#         store_id  product_id day_of_week    month  year hour  \
# ...

# %%
import pandas as pd
from sqlalchemy import create_engine

# === RDS MySQL Connection Details ===
rds_endpoint = "rm-3ns023t5i1ctk89e5go.mysql.rds.aliyuncs.com"
rds_port = 3306
rds_dbname = 'cleaned_data'
rds_user = 'adminAcc'
rds_pass = 'Test1234'

# === Create SQLAlchemy engine ===
engine = create_engine(f'mysql+pymysql://{rds_user}:{rds_pass}@{rds_endpoint}:{rds_port}/{rds_dbname}')

# === Upload to RDS: auto-create table, overwrite if exists ===
df.to_sql('cleaned_data', con=engine, index=False, if_exists='replace')

print("Table created/replaced and data uploaded successfully.")
# Out:
# Table created/replaced and data uploaded successfully.

# %%
df.columns
# Out:
# Index(['transaction_id', 'transaction_date', 'transaction_time',
#        'transaction_qty', 'store_id', 'product_id', 'day_of_week', 'month',
#        'year', 'hour', 'is_public_holiday', 'holiday_name', 'is_weekend',
#        'day_of_month', 'week_of_month'],
#       dtype='object')

# %%
# Step 1: Group transaction quantities by date and product
daily_qty = df.groupby(['transaction_date', 'product_id'])['transaction_qty'].sum().reset_index()

# Step 2: Join with product_info to get unit price (like SQL JOIN)
daily_sales = daily_qty.merge(product_info[['product_id', 'unit_price']], on='product_id', how='left')

# Step 3: Calculate sales value in usd
daily_sales['daily_product_sales_usd'] = daily_sales['transaction_qty'] * daily_sales['unit_price']

# step 4: sales value truncate to 2 decimal
daily_sales['daily_product_sales_usd'] = daily_sales['daily_product_sales_usd'].apply(lambda x: "{:.2f}".format(x))

daily_sales
# Out:
#       transaction_date  product_id  transaction_qty  unit_price  \
# 0           2023-01-01          22               15        2.00
# 1           2023-01-01          23               21        2.50
# 2           2023-01-01          24               18        3.00
# 3           2023-01-01          25               23        2.20
# 4           2023-01-01          26               14        3.00
# ...                ...         ...              ...         ...
# 12127       2023-06-30          78               19        4.50
# 12128       2023-06-30          79               12        4.69
# 12129       2023-06-30          83                6       23.00
# 12130       2023-06-30          84               23        0.80
# 12131       2023-06-30          87               18        2.10
#
#       daily_product_sales_usd
# 0                       30.00
# 1                       52.50
# 2                       54.00
# 3                       50.60
# 4                       42.00
# ...

# %%
# Step 1: Merge df with product_info to get unit prices
merged = df.merge(product_info[['product_id', 'unit_price']], on='product_id', how='left')

# Step 2: Calculate RM value per row (transaction line)
merged['transaction_value'] = merged['transaction_qty'] * merged['unit_price']

# Step 3: Group by date and sum
daily_total_sales = (
    merged
    .groupby('transaction_date')['transaction_value']
    .sum()
    .reset_index()
    .rename(columns={'transaction_value': 'daily_total_sales_usd'})
)

# daily total sales truncate to 2 decimal
daily_total_sales['daily_total_sales_usd'] = daily_total_sales['daily_total_sales_usd'].apply(lambda x: "{:.2f}".format(x))

daily_total_sales
# Out:
#     transaction_date daily_total_sales_usd
# 0         2023-01-01               2520.42
# 1         2023-01-02               2418.37
# 2         2023-01-03               2575.51
# 3         2023-01-04               2229.49
# 4         2023-01-05               2424.29
# ..               ...                   ...
# 176       2023-06-26               5925.68
# 177       2023-06-27               6003.01
# 178       2023-06-28               4769.14
# 179       2023-06-29               4495.33
# 180       2023-06-30               5582.33
#
# [181 rows x 2 columns]

# %% [markdown]
# # Simulate inventory

# %%
import pandas as pd
import numpy as np

# Assume daily_sales is already created and sorted
daily_sales = daily_sales.sort_values(['product_id', 'transaction_date'])

# Create an empty list to store rows
inventory_records = []

# Simulate per product
for product_id, group in daily_sales.groupby('product_id'):
    previous_closing_stock = 100  # start with a fixed opening stock
    max_wastage = 30  # initial high wastage to simulate improvement
    for idx, row in group.iterrows():
        date = row['transaction_date']
        units_sold = row['transaction_qty']
        
        # Simulate purchase quantity (could be random or fixed, here we use fixed + small noise)
        purchases = np.random.randint(10, 30)
        
        # Simulate wastage reducing over time
        wastage = max(0, int(np.random.uniform(0, max_wastage)))
        max_wastage = max(0, max_wastage + 0.1)  # slowly decrease allowed max wastage
        
        # Calculate available stock
        available_stock = previous_closing_stock + purchases
        
        # Calculate closing stock
        closing_stock = available_stock - units_sold - wastage
        
        # Ensure closing stock is not negative
        if closing_stock < 0:
            closing_stock = 0
            wastage = available_stock - units_sold  # adjust wastage accordingly
            wastage = max(0, wastage)  # make sure wastage is not negative again
        
        inventory_records.append({
            'transaction_date': date,
            'product_id': product_id,
            'opening_stock': previous_closing_stock,
            'purchases': purchases,
            'closing_stock': closing_stock,
            'units_sold': units_sold,
            'wastage': wastage
        })
        
        # Next day's opening stock is today's closing
        previous_closing_stock = closing_stock

# Create DataFrame
inventory_daily = pd.DataFrame(inventory_records)

# sort by transaction date, then nested by sort by product id
inventory_daily = inventory_daily.sort_values(['transaction_date', 'product_id']).reset_index(drop=True)
inventory_daily
# Out:
#       transaction_date  product_id  opening_stock  purchases  closing_stock  \
# 0           2023-01-01          22            100         23            101
# 1           2023-01-01          23            100         13             68
# 2           2023-01-01          24            100         28            106
# 3           2023-01-01          25            100         14             82
# 4           2023-01-01          26            100         20             88
# ...                ...         ...            ...        ...            ...
# 12127       2023-06-30          78              0         29              0
# 12128       2023-06-30          79              0         29              0
# 12129       2023-06-30          83            133         26            138
# 12130       2023-06-30          84              0         17              0
# 12131       2023-06-30          87              0         22              0
#
#        units_sold  wastage
# 0              15        7
# ...

# %%
import matplotlib.pyplot as plt

avg_wastage = inventory_daily.groupby('transaction_date')['wastage'].mean()

plt.plot(avg_wastage.index, avg_wastage.values)
plt.title("Average Daily Wastage (Simulated)")
plt.xlabel("Date")
plt.ylabel("Average Wastage Units")
plt.xticks(rotation=45)
plt.grid(True)
plt.tight_layout()
plt.show()

# %%
inventory_daily.to_sql('inventory', con=engine, index=False, if_exists='replace')
# Out:
# 12132

# %%
inventory_daily.columns
# Out:
# Index(['transaction_date', 'product_id', 'opening_stock', 'purchases',
#        'closing_stock', 'units_sold', 'wastage'],
#       dtype='object')
